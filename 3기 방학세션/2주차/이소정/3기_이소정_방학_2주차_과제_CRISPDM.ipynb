# %% [markdown]
# ### 간단한 DF

# %%
import pandas as pd
import numpy

df1 = pd.DataFrame({
    "customer_id": [1, 2, 3, 4],
    "name": ["A", "B", "C", "D"]
})

df2 = pd.DataFrame({
    "order_id": [101, 102, 103, 104],
    "customer_id": [1, 1, 2, 5],
    "amount": [30000, 12000, 45000, 9999]
})

df1, df2
# Out:
# (   customer_id name
#  0            1    A
#  1            2    B
#  2            3    C
#  3            4    D,
#     order_id  customer_id  amount
#  0       101            1   30000
#  1       102            1   12000
#  2       103            2   45000
#  3       104            5    9999)

# %% [markdown]
# ### INNER JOIN : 양쪽에 모두 있는 행만 합치기

# %%
inner = pd.merge(df1, df2, on="customer_id", how="inner")
inner
# Out:
#    customer_id name  order_id  amount
# 0            1    A       101   30000
# 1            1    A       102   12000
# 2            2    B       103   45000

# %% [markdown]
# ### LEFT JOIN : 왼쪽 전부 살리기

# %%
left = pd.merge(df1, df2, on="customer_id", how="left")
left
# Out:
#    customer_id name  order_id   amount
# 0            1    A     101.0  30000.0
# 1            1    A     102.0  12000.0
# 2            2    B     103.0  45000.0
# 3            3    C       NaN      NaN
# 4            4    D       NaN      NaN

# %%
left_only = left[left["order_id"].isnull()]
left_only
# Out:
#    customer_id name  order_id  amount
# 3            3    C       NaN     NaN
# 4            4    D       NaN     NaN

# %% [markdown]
# ### RIGHT JOIN : 오른쪽 전부 살리기

# %%
right = pd.merge(df1, df2, on="customer_id", how="right")
right
# Out:
#    customer_id name  order_id  amount
# 0            1    A       101   30000
# 1            1    A       102   12000
# 2            2    B       103   45000
# 3            5  NaN       104    9999

# %%
right_only = right[right["name"].isnull()]
right_only
# Out:
#    customer_id name  order_id  amount
# 3            5  NaN       104    9999

# %% [markdown]
# ### FULL OUTER JOIN : 양쪽 모든 행 합치기

# %%
outer = pd.merge(df1, df2, on="customer_id", how="outer", indicator=True)
outer
# Out:
#    customer_id name  order_id   amount      _merge
# 0            1    A     101.0  30000.0        both
# 1            1    A     102.0  12000.0        both
# 2            2    B     103.0  45000.0        both
# 3            3    C       NaN      NaN   left_only
# 4            4    D       NaN      NaN   left_only
# 5            5  NaN     104.0   9999.0  right_only

# %% [markdown]
# ### CONCAT

# %%
concat = pd.concat([df1, df2])
concat
# Out:
#    customer_id name  order_id   amount
# 0            1    A       NaN      NaN
# 1            2    B       NaN      NaN
# 2            3    C       NaN      NaN
# 3            4    D       NaN      NaN
# 0            1  NaN     101.0  30000.0
# 1            1  NaN     102.0  12000.0
# 2            2  NaN     103.0  45000.0
# 3            5  NaN     104.0   9999.0

# %%
concat = pd.concat([df1, df2], axis=1)
concat
# Out:
#    customer_id name  order_id  customer_id  amount
# 0            1    A       101            1   30000
# 1            2    B       102            1   12000
# 2            3    C       103            2   45000
# 3            4    D       104            5    9999

# %% [markdown]
# ### Olist data join

# %%
import pandas as pd

#파일 불러오기
customers = pd.read_csv("olist_customers_dataset.csv")
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
order_payments = pd.read_csv("olist_order_payments_dataset.csv")
order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
product_category = pd.read_csv("product_category_name_translation.csv")

#조인하기
merged_df = pd.merge(orders, customers, on="customer_id", how="inner")
merged_df = pd.merge(merged_df, order_items, on="order_id", how="inner")
merged_df = pd.merge(merged_df, products, on="product_id", how="left")
merged_df = pd.merge(merged_df, product_category, on="product_category_name", how="left")
merged_df = pd.merge(merged_df, sellers, on="seller_id", how="left")
merged_df = pd.merge(merged_df, order_payments, on="order_id", how="left")
merged_df = pd.merge(merged_df, order_reviews, on="order_id", how="left")

display(merged_df)
print(merged_df.columns)
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118305  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118306  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118307  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118308  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118309  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 0         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3         delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4         delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# ...             ...                      ...                  ...
# 118305    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 118306    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 118307    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 118308    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 118309    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-10-04 19:55:00           2017-10-10 21:25:13
# 1               2017-10-04 19:55:00           2017-10-10 21:25:13
# 2               2017-10-04 19:55:00           2017-10-10 21:25:13
# 3               2018-07-26 14:31:00           2018-08-07 15:27:45
# 4               2018-08-08 13:50:00           2018-08-17 18:06:29
# ...                             ...                           ...
# 118305          2018-02-07 23:22:42           2018-02-28 17:37:56
# 118306          2017-08-28 20:52:26           2017-09-21 11:24:17
# 118307          2018-01-12 15:35:03           2018-01-25 23:32:54
# 118308          2018-01-12 15:35:03           2018-01-25 23:32:54
# 118309          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#        order_estimated_delivery_date                customer_unique_id  \
# 0                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 3                2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 4                2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# ...                              ...                               ...
# 118305           2018-03-02 00:00:00  da62f9e57a76d978d02ab5362c509660
# 118306           2017-09-27 00:00:00  737520a9aad80b3fbbdad19b66b37b30
# 118307           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 118308           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 118309           2018-04-03 00:00:00  60350aa974b26ff12caad89e55993bd6
#
#         customer_zip_code_prefix  ... payment_sequential payment_type  \
# 0                           3149  ...                1.0  credit_card
# 1                           3149  ...                3.0      voucher
# 2                           3149  ...                2.0      voucher
# 3                          47813  ...                1.0       boleto
# 4                          75265  ...                1.0  credit_card
# ...                          ...  ...                ...          ...
# 118305                     11722  ...                1.0  credit_card
# 118306                     45920  ...                1.0  credit_card
# 118307                     28685  ...                1.0  credit_card
# 118308                     28685  ...                1.0  credit_card
# 118309                     83750  ...                1.0   debit_card
#
#         payment_installments payment_value                         review_id  \
# 0                        1.0         18.12  a54f0611adc9ed256b57ede6b6eb5114
# 1                        1.0          2.00  a54f0611adc9ed256b57ede6b6eb5114
# 2                        1.0         18.59  a54f0611adc9ed256b57ede6b6eb5114
# 3                        1.0        141.46  8d5266042046a06655c8db133d120ba5
# 4                        3.0        179.12  e73b67b67587f7644d5bd1a52deb1b01
# ...                      ...           ...                               ...
# 118305                   3.0        195.00  29bb71b2760d0f876dfa178a76bc4734
# 118306                   5.0        271.01  371579771219f6db2d830d50805977bb
# 118307                   4.0        441.16  8ab6855b9fe9b812cd03a480a25058a1
# 118308                   4.0        441.16  8ab6855b9fe9b812cd03a480a25058a1
# 118309                   1.0         86.86  dc9c59b4688062c25758c2be4cafc523
#
#        review_score  review_comment_title  \
# 0               4.0                   NaN
# 1               4.0                   NaN
# 2               4.0                   NaN
# 3               4.0      Muito boa a loja
# 4               5.0                   NaN
# ...             ...                   ...
# 118305          4.0                   NaN
# 118306          5.0                   NaN
# 118307          2.0                   NaN
# 118308          2.0                   NaN
# 118309          5.0                   NaN
#
#                                    review_comment_message  \
# 0       Não testei o produto ainda, mas ele veio corre...
# 1       Não testei o produto ainda, mas ele veio corre...
# 2       Não testei o produto ainda, mas ele veio corre...
# 3                                    Muito bom o produto.
# 4                                                     NaN
# ...                                                   ...
# 118305       So uma peça que veio rachado mas tudo bem rs
# 118306                       Foi entregue antes do prazo.
# 118307  Foi entregue somente 1. Quero saber do outro p...
# 118308  Foi entregue somente 1. Quero saber do outro p...
# 118309                                                NaN
#
#        review_creation_date  review_answer_timestamp
# 0       2017-10-11 00:00:00      2017-10-12 03:43:48
# 1       2017-10-11 00:00:00      2017-10-12 03:43:48
# 2       2017-10-11 00:00:00      2017-10-12 03:43:48
# 3       2018-08-08 00:00:00      2018-08-08 18:37:50
# 4       2018-08-18 00:00:00      2018-08-22 19:07:58
# ...                     ...                      ...
# 118305  2018-03-01 00:00:00      2018-03-02 17:50:01
# 118306  2017-09-22 00:00:00      2017-09-22 23:10:57
# 118307  2018-01-26 00:00:00      2018-01-27 09:16:56
# 118308  2018-01-26 00:00:00      2018-01-27 09:16:56
# 118309  2018-03-17 00:00:00      2018-03-17 16:33:31
#
# [118310 rows x 40 columns]
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')
