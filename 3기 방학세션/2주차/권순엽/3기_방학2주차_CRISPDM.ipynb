# %% [markdown]
# ###간단한 DF

# %%
import pandas as pd
import numpy

df1 = pd.DataFrame({
    "customer_id": [1, 2, 3, 4],
    "name": ["A", "B", "C", "D"]
})

df2 = pd.DataFrame({
    "order_id": [101, 102, 103, 104],
    "customer_id": [1, 1, 2, 5],
    "amount": [30000, 12000, 45000, 9999]
})

df1, df2
# Out:
# (   customer_id name
#  0            1    A
#  1            2    B
#  2            3    C
#  3            4    D,
#     order_id  customer_id  amount
#  0       101            1   30000
#  1       102            1   12000
#  2       103            2   45000
#  3       104            5    9999)

# %% [markdown]
# ###INNER JOIN : 양쪽에 모두 있는 행만 합치기

# %%
inner = pd.merge(df1, df2, on="customer_id", how="inner")
inner
# Out:
#    customer_id name  order_id  amount
# 0            1    A       101   30000
# 1            1    A       102   12000
# 2            2    B       103   45000

# %% [markdown]
# ###LEFT JOIN : 왼쪽 전부 살리기

# %%
left = pd.merge(df1, df2, on="customer_id", how="left")
left
# Out:
#    customer_id name  order_id   amount
# 0            1    A     101.0  30000.0
# 1            1    A     102.0  12000.0
# 2            2    B     103.0  45000.0
# 3            3    C       NaN      NaN
# 4            4    D       NaN      NaN

# %%
left_only = left[left["order_id"].isnull()]
left_only
# Out:
#    customer_id name  order_id  amount
# 3            3    C       NaN     NaN
# 4            4    D       NaN     NaN

# %% [markdown]
# ###RIGHT JOIN : 오른쪽 전부 살리기

# %%
right = pd.merge(df1, df2, on="customer_id", how="right")
right
# Out:
#    customer_id name  order_id  amount
# 0            1    A       101   30000
# 1            1    A       102   12000
# 2            2    B       103   45000
# 3            5  NaN       104    9999

# %%
right_only = right[right["name"].isnull()]
right_only
# Out:
#    customer_id name  order_id  amount
# 3            5  NaN       104    9999

# %% [markdown]
# ###FULL OUTER JOIN : 양쪽 모든 행 합치기

# %%
outer = pd.merge(df1, df2, on="customer_id", how="outer")
outer
# Out:
#    customer_id name  order_id   amount
# 0            1    A     101.0  30000.0
# 1            1    A     102.0  12000.0
# 2            2    B     103.0  45000.0
# 3            3    C       NaN      NaN
# 4            4    D       NaN      NaN
# 5            5  NaN     104.0   9999.0

# %% [markdown]
# ###CONCAT

# %%
concat = pd.concat([df1, df2])
concat
# Out:
#    customer_id name  order_id   amount
# 0            1    A       NaN      NaN
# 1            2    B       NaN      NaN
# 2            3    C       NaN      NaN
# 3            4    D       NaN      NaN
# 0            1  NaN     101.0  30000.0
# 1            1  NaN     102.0  12000.0
# 2            2  NaN     103.0  45000.0
# 3            5  NaN     104.0   9999.0

# %%
concat = pd.concat([df1, df2], axis=1)
concat
# Out:
#    customer_id name  order_id  customer_id  amount
# 0            1    A       101            1   30000
# 1            2    B       102            1   12000
# 2            3    C       103            2   45000
# 3            4    D       104            5    9999

# %% [markdown]
# ###Olist data join

# %%
import pandas as pd

#파일 불러오기
customers = pd.read_csv("olist_customers_dataset.csv")
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
order_payments = pd.read_csv("olist_order_payments_dataset.csv")
order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
product_category = pd.read_csv("product_category_name_translation.csv")

#조인하기
merged_df = pd.merge(orders, order_items, on="order_id", how="outer")
merged_df = pd.merge(merged_df, order_payments, on="order_id", how="outer")
merged_df = pd.merge(merged_df, order_reviews, on="order_id", how="outer")
merged_df = pd.merge(merged_df, products, on="product_id", how="outer")
merged_df = pd.merge(merged_df, customers, on="customer_id", how="outer")
merged_df = pd.merge(merged_df, sellers, on="seller_id", how="outer")
display(merged_df)
print(merged_df.columns)
# Out:
#                                 order_id                       customer_id  \
# 0       d455a8cb295653b55abda06d434ab492  944b72539d7e1f7f7fc6e46639ef1fe3
# 1       7f39ba4c9052be115350065d07583cac  d7fc82cbeafea77bd0a8fbbf6296e387
# 2       9dc8d1a6f16f1b89874c29c9d8d30447  d9442164acf4b03109425633efaa0cfc
# 3       0f548bd29148ebc519d6495e37a284e1  015faf9ec36eccd957c0f2782aab09a4
# 4       0f548bd29148ebc519d6495e37a284e1  015faf9ec36eccd957c0f2782aab09a4
# ...                                  ...                               ...
# 119138  87ae60ef8b08ae0e5f903cacb53a6904  fea4d57ed3a45455f89c25ef3dae8ee8
# 119139  d69fcef5a5fe3a3db60ea65c6ee499cc  ff0340330283c0d05ea7281e67fa2e76
# 119140  f86d7bc39aab05299691322044b63bb2  ff31bee1ba4bba00cc14b1b91c8d28f3
# 119141  74f833bf7c70ce8c3f820f725c213e1c  fffc22669ca576ae3f654ea64c8f36be
# 119142  2e935fa1d39497aa0ec3f1107fbfb5b8  ffffe8b65bbe3087b653a978c870db99
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...
