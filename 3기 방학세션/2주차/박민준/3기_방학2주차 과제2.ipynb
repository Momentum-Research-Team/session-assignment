# %%
import pandas as pd
import numpy

customers=pd.DataFrame({
    "customer_id":[1,2,3,4],
    "name":["A","B","C","D"]
})

orders=pd.DataFrame({
    "order_id":[101,102,103,104],
    "customer_id":[1,1,2,5],
    "amout":[30000,12000,45000,9999]
})

customers,orders
# Out:
# (   customer_id name
#  0            1    A
#  1            2    B
#  2            3    C
#  3            4    D,
#     order_id  customer_id  amout
#  0       101            1  30000
#  1       102            1  12000
#  2       103            2  45000
#  3       104            5   9999)

# %%
inner=pd.merge(customers,orders,on="customer_id",how="inner")
inner
# Out:
#    customer_id name  order_id  amout
# 0            1    A       101  30000
# 1            1    A       102  12000
# 2            2    B       103  45000

# %%
left=pd.merge(customers,orders,on="customer_id",how="left")
left
# Out:
#    customer_id name  order_id    amout
# 0            1    A     101.0  30000.0
# 1            1    A     102.0  12000.0
# 2            2    B     103.0  45000.0
# 3            3    C       NaN      NaN
# 4            4    D       NaN      NaN

# %%
left_only=left[left["order_id"].isnull()]
left_only
# Out:
#    customer_id name  order_id  amout
# 3            3    C       NaN    NaN
# 4            4    D       NaN    NaN

# %%
outer=pd.merge(customers,orders,on="customer_id",how="outer")
outer
# Out:
#    customer_id name  order_id    amout
# 0            1    A     101.0  30000.0
# 1            1    A     102.0  12000.0
# 2            2    B     103.0  45000.0
# 3            3    C       NaN      NaN
# 4            4    D       NaN      NaN
# 5            5  NaN     104.0   9999.0

# %%
concat=pd.concat([customers,orders])
concat
# Out:
#    customer_id name  order_id    amout
# 0            1    A       NaN      NaN
# 1            2    B       NaN      NaN
# 2            3    C       NaN      NaN
# 3            4    D       NaN      NaN
# 0            1  NaN     101.0  30000.0
# 1            1  NaN     102.0  12000.0
# 2            2  NaN     103.0  45000.0
# 3            5  NaN     104.0   9999.0

# %%
concat=pd.concat([customers,orders],axis=1)
concat
# Out:
#    customer_id name  order_id  customer_id  amout
# 0            1    A       101            1  30000
# 1            2    B       102            1  12000
# 2            3    C       103            2  45000
# 3            4    D       104            5   9999
